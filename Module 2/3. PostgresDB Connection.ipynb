# %% [markdown]
# # PostgresDB Connection using Python

# %%
# !pip install psycopg2
# !pip install psycopg2-binary --user

# %%
host=r"postgresql-course-demo.cxm9bldw9js2.ap-south-1.rds.amazonaws.com"  # Your RDS endpoint
port="5432"                              # Default PostgreSQL port
database="ai_agent_db"                 # Your database name
user="postgres"                        # Your PostgreSQL username
password="agent-007~!"                # Your PostgreSQL password

# %% [markdown]
# ## Connecting PostgresDB using psycopg2

# %%
import psycopg2
from psycopg2 import OperationalError

def create_connection():
    connection = None
    try:
        # Create a connection to your PostgreSQL RDS instance
        connection = psycopg2.connect(
            database=database,
            user=user,
            password=password,
            host=host,
            port=port
        )
        print("Connection to PostgreSQL DB successful")
    
    except OperationalError as e:
        print(f"The error '{e}' occurred")
    
    return connection

def execute_query(connection, query):
    cursor = connection.cursor()
    try:
        cursor.execute(query)
        connection.commit()
        print("Query execaauted successfully")
    except Exception as e:
        print(f"The error '{e}' occurred")

# %%
# Example usage
connection = create_connection()
if connection:
    query = "SELECT version();"  # Example query to get PostgreSQL version
    execute_query(connection, query)
# Out:
# Connection to PostgreSQL DB successful
# Query execaauted successfully

# %%
connection.close()  # Close the connection when done

# %% [markdown]
# ## Connecting PostgresDB using SQLAlchemy

# %%
import pandas as pd
from sqlalchemy import create_engine

# Create a connection string
connection_string = f'postgresql+psycopg2://{user}:{password}@{host}:{port}/{database}'

# Create an SQLAlchemy engine
engine = create_engine(connection_string)

# SQL query to fetch data from the Students table
query = "SELECT * FROM Students;"

# Execute the query and load data into a Pandas DataFrame
df = pd.read_sql(query, con=engine)

# Display the DataFrame
df
# Out:
#     id               name  age  statistics_marks  python_marks  ml_marks  \
# 0    1        Aarav Patel   20                85            90        88
# 1    2       Sophia Smith   21                75            78        82
# 2    3       Liam Johnson   22                88            91        84
# 3    4       Saanvi Gupta   19                92            89        95
# 4    5       Olivia Brown   23                80            87        85
# 5    6  Isabella Williams   20                85            88        90
# 6    7       Rohan Sharma   21                78            80        82
# 7    8         Noah Jones   22                90            92        91
# 8    9         Mia Davies   21                85            86        88
# 9   10      Krishna Kumar   20                82            87        83
# 10  11       James Wilson   22                78            79        84
# 11  12        Aditi Desai   19                90            92        88
# 12  13   Charlotte Garcia   23                88            91        89
# 13  14    Elijah Martinez   20                87            89        88
# 14  15        Emily Clark   22                79            82        80
# 15  16       Ishaan Mehta   21                85            87        89
# 16  17       Amelia Lewis   23                83            86        84
# 17  18      Jayden Walker   19                86            89        88
# 18  19       Ananya Verma   22                91            93        94
# 19  20        Ethan Scott   21                84            87        85
#
#     dl_marks
# 0         92
# 1         85
# 2         89
# 3         91
# 4         90
# 5         89
# 6         84
# 7         93
# 8         84
# 9         85
# 10        86
# 11        89
# 12        92
# 13        90
# 14        84
# 15        88
# 16        87
# 17        91
# 18        92
# 19        88

# %% [markdown]
# ## Connecting PostgresDB using Pandas

# %%
import pandas as pd
import psycopg2

# Create connection using psycopg2
connection = psycopg2.connect(
            database=database,
            user=user,
            password=password,
            host=host,
            port=port
        )

# Execute query and fetch data into Pandas DataFrame
df = pd.read_sql("SELECT * FROM Students", con=connection)
df
# Out:
# /tmp/ipykernel_43384/3653347620.py:14: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   df = pd.read_sql("SELECT * FROM Students", con=connection)
#     id               name  age  statistics_marks  python_marks  ml_marks  \
# 0    1        Aarav Patel   20                85            90        88
# 1    2       Sophia Smith   21                75            78        82
# 2    3       Liam Johnson   22                88            91        84
# 3    4       Saanvi Gupta   19                92            89        95
# 4    5       Olivia Brown   23                80            87        85
# 5    6  Isabella Williams   20                85            88        90
# 6    7       Rohan Sharma   21                78            80        82
# 7    8         Noah Jones   22                90            92        91
# 8    9         Mia Davies   21                85            86        88
# 9   10      Krishna Kumar   20                82            87        83
# 10  11       James Wilson   22                78            79        84
# 11  12        Aditi Desai   19                90            92        88
# 12  13   Charlotte Garcia   23                88            91        89
# 13  14    Elijah Martinez   20                87            89        88
# 14  15        Emily Clark   22                79            82        80
# 15  16       Ishaan Mehta   21                85            87        89
# 16  17       Amelia Lewis   23                83            86        84
# 17  18      Jayden Walker   19                86            89        88
# 18  19       Ananya Verma   22                91            93        94
# 19  20        Ethan Scott   21                84            87        85
#
#     dl_marks
# 0         92
# 1         85
# 2         89
# 3         91
# 4         90
# 5         89
# 6         84
# 7         93
# 8         84
# 9         85
# 10        86
# 11        89
# 12        92
# 13        90
# 14        84
# 15        88
# 16        87
# 17        91
# 18        92
# 19        88

# %%
connection.close()
